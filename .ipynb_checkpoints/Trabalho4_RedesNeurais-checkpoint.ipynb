# %% [markdown]
# # Trabalho 4 - Redes Neurais
# Desenvolver um experimento completo usando LSTMs para uma aplicação sequencial. Exemplos de aplicações: classificação de vídeo, tradução, ...

# %% [markdown]
# ## Imports
# Primeiro é preciso importar as bibliotecas e funções a serem utilizadas.

# %%
import math
import torch
import torch.utils.data as data_utils
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler

# %%
sequence_length = 60
input_size = 1
hidden_size = 25
output_size = 1
learning_rate = 0.001
batch_size = 1

# %% [markdown]
# ## Pegando os datasets
# Utilizando o dataset CIFAR10 que possui link direto com o torchvision. É um dataset constituidos por imagens coloridas de veículos e animais onde existem 10 classes diferentes. O objetivo é criar um classificador a partir de uma LSTM.
#
# [Link para o dataset](http://www.cs.toronto.edu/~nitish/unsupervised_video/)

# %%
stock_data = yf.download('AAPL', start='2010-01-01', end='2023-06-13')
#PETR4.SA
stock_data = stock_data.dropna()
stock_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.496294  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.507525  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.404015  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.392176  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.434674  447610800

# %%
stock_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.496294
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.507525
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.404015
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.392176
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.434674
# ...                ...         ...         ...         ...         ...
# 2023-06-06  179.970001  180.119995  177.429993  179.210007  179.210007
# 2023-06-07  178.440002  181.210007  177.320007  177.820007  177.820007
# 2023-06-08  177.899994  180.839996  177.460007  180.570007  180.570007
# 2023-06-09  181.500000  182.229996  180.630005  180.960007  180.960007
# 2023-06-12  181.270004  183.889999  180.970001  183.789993  183.789993
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2023-06-06   64848400
# 2023-06-07   61944600
# 2023-06-08   50214900
# 2023-06-09   48870700
# 2023-06-12   54274900
#
# [3383 rows x 6 columns]

# %%
plt.figure(figsize=(15, 8))
plt.title('Stock Prices History')
plt.plot(stock_data['Close'])
plt.xlabel('Date')
plt.ylabel('Prices ($)')
# Out:
# Text(0, 0.5, 'Prices ($)')

# %%
close_prices = stock_data['Close']
values = close_prices.values
training_data_len = math.ceil(len(values)* 0.8)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(values.reshape(-1,1))
train_data = scaled_data[0: training_data_len, :]

x_train = []
y_train = []

for i in range(sequence_length, len(train_data)):
    x_train.append(train_data[i-sequence_length:i, 0])
    y_train.append(train_data[i, 0])
    
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
test_data = scaled_data[training_data_len-sequence_length: , : ]
x_test = []
y_test = values[training_data_len:]

for i in range(sequence_length, len(test_data)):
  x_test.append(test_data[i-sequence_length:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_train_t, x_valid, y_train_t, y_valid = train_test_split(x_train, y_train, test_size=0.2, shuffle=False)
print("Shape do treino: ", x_train.shape)
print("Shape do teste: ", x_test.shape)
print("Shape da validação: ", x_valid.shape)
# Out:
# Shape do treino:  (2647, 60, 1)
# Shape do teste:  (676, 60, 1)
# Shape da validação:  (530, 60, 1)

# %%
train = torch.tensor(x_train_t.astype(np.float32))
train_target = torch.tensor(y_train_t.astype(np.float32))
train_tensor = data_utils.TensorDataset(train, train_target) 
train_loader = data_utils.DataLoader(dataset = train_tensor, batch_size = batch_size, shuffle = True)

# %%
valid = torch.tensor(x_valid.astype(np.float32))
valid_target = torch.tensor(y_valid.astype(np.float32))
valid_tensor = data_utils.TensorDataset(valid, valid_target) 
valid_loader = data_utils.DataLoader(dataset = valid_tensor, batch_size = batch_size, shuffle = True)

# %% [markdown]
# ## Definindo o device
# Como minha placa de vídeo é AMD não possuo Cuda.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
    
    def __init__(self, input_len, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.lstm = nn.LSTM(input_len, hidden_size, batch_first=True)
        self.output = nn.Linear(hidden_size, output_size)
        
    def forward(self, input):
        lstm_out, _ = self.lstm(input)
        out = self.output(lstm_out[:, -1, :])
        return out

# %%
model = NeuralNetwork(input_size, hidden_size, output_size).to(device)
print(model)
# Out:
# NeuralNetwork(
#   (lstm): LSTM(1, 25, batch_first=True)
#   (output): Linear(in_features=25, out_features=1, bias=True)
# )

# %%
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)

    loss_sum = 0
    i = 0
    for X, y in dataloader:
        X = X.reshape(-1, sequence_length, input_size)
        pred = model(X)

        loss = loss_fn(pred, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item() * len(X)
        
    avg_loss = loss_sum / size 
    print(f"Train Error: Avg loss = {avg_loss:>8f}")
    return avg_loss

# %%
def valid_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    loss, correct = 0, 0

    with torch.no_grad():
      for X, y in dataloader:
          pred = model(X)
          loss += loss_fn(pred, y).item() * len(X)

    avg_loss = loss / size
    print(f"Valid Error: Avg loss = {avg_loss:>8f}")
    
    return avg_loss

# %%
n_epoch = 50
loss_valid_history = []
loss_train_history = []
min_loss_valid = np.Inf


for epoch in range(n_epoch):
    print(f"Epoch {epoch+1}\n-----------------------------------")
    loss_train = train_loop(train_loader, model, loss_fn, optimizer)
    loss_valid = valid_loop(valid_loader, model, loss_fn)
    if  loss_valid <= min_loss_valid:
        print(f"Validation loss decreased ({min_loss_valid:>0.6f} --> {loss_valid:>0.6f}).  Saving model ...")
        min_loss_valid = loss_valid
        torch.save(model.state_dict(), 'models/best_model_trab4.pt')
    print("-----------------------------------\n")


    loss_train_history.append(loss_train)
    loss_valid_history.append(loss_valid)
# Out:
# Epoch 1
# -----------------------------------
# C:\Users\sergi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\nn\modules\loss.py:536: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Train Error: Avg loss = 0.000687
# Valid Error: Avg loss = 0.001280
# Validation loss decreased (inf --> 0.001280).  Saving model ...
# -----------------------------------
#
# Epoch 2
# -----------------------------------
# Train Error: Avg loss = 0.000036
# Valid Error: Avg loss = 0.000308
# Validation loss decreased (0.001280 --> 0.000308).  Saving model ...
# -----------------------------------
#
# Epoch 3
# -----------------------------------
# Train Error: Avg loss = 0.000031
# Valid Error: Avg loss = 0.000400
# -----------------------------------
#
# Epoch 4
# -----------------------------------
# Train Error: Avg loss = 0.000027
# Valid Error: Avg loss = 0.000389
# -----------------------------------
#
# Epoch 5
# -----------------------------------
# Train Error: Avg loss = 0.000020
# Valid Error: Avg loss = 0.000226
# Validation loss decreased (0.000308 --> 0.000226).  Saving model ...
# -----------------------------------
#
# Epoch 6
# -----------------------------------
# Train Error: Avg loss = 0.000018
# Valid Error: Avg loss = 0.000235
# -----------------------------------
#
# Epoch 7
# -----------------------------------
# Train Error: Avg loss = 0.000015
# Valid Error: Avg loss = 0.000255
# -----------------------------------
#
# Epoch 8
# -----------------------------------
# Train Error: Avg loss = 0.000013
# Valid Error: Avg loss = 0.000248
# -----------------------------------
#
# Epoch 9
# -----------------------------------
# Train Error: Avg loss = 0.000012
# Valid Error: Avg loss = 0.000139
# Validation loss decreased (0.000226 --> 0.000139).  Saving model ...
# -----------------------------------
#
# Epoch 10
# -----------------------------------
# Train Error: Avg loss = 0.000011
# Valid Error: Avg loss = 0.000197
# -----------------------------------
#
# Epoch 11
# -----------------------------------
# Train Error: Avg loss = 0.000012
# Valid Error: Avg loss = 0.000234
# -----------------------------------
#
# Epoch 12
# -----------------------------------
# Train Error: Avg loss = 0.000011
# Valid Error: Avg loss = 0.000159
# -----------------------------------
#
# Epoch 13
# -----------------------------------
# Train Error: Avg loss = 0.000011
# Valid Error: Avg loss = 0.000218
# -----------------------------------
#
# Epoch 14
# -----------------------------------
# Train Error: Avg loss = 0.000010
# Valid Error: Avg loss = 0.000384
# -----------------------------------
#
# Epoch 15
# -----------------------------------
# Train Error: Avg loss = 0.000010
# Valid Error: Avg loss = 0.000348
# -----------------------------------
#
# Epoch 16
# -----------------------------------
# Train Error: Avg loss = 0.000010
# Valid Error: Avg loss = 0.000389
# -----------------------------------
#
# Epoch 17
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000228
# -----------------------------------
#
# Epoch 18
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000301
# -----------------------------------
#
# Epoch 19
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000343
# -----------------------------------
#
# Epoch 20
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000411
# -----------------------------------
#
# Epoch 21
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000512
# -----------------------------------
#
# Epoch 22
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000377
# -----------------------------------
#
# Epoch 23
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000476
# -----------------------------------
#
# Epoch 24
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000298
# -----------------------------------
#
# Epoch 25
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000354
# -----------------------------------
#
# Epoch 26
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000495
# -----------------------------------
#
# Epoch 27
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000369
# -----------------------------------
#
# Epoch 28
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000562
# -----------------------------------
#
# Epoch 29
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000557
# -----------------------------------
#
# Epoch 30
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000545
# -----------------------------------
#
# Epoch 31
# -----------------------------------
# Train Error: Avg loss = 0.000009
# Valid Error: Avg loss = 0.000349
# -----------------------------------
#
# Epoch 32
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000381
# -----------------------------------
#
# Epoch 33
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000437
# -----------------------------------
#
# Epoch 34
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000415
# -----------------------------------
#
# Epoch 35
# -----------------------------------
# Train Error: Avg loss = 0.000008
# Valid Error: Avg loss = 0.000502
# -----------------------------------
#
# Epoch 36
# -----------------------------------

# %%
epoch_vec = list(range(1, n_epoch+1))

plt.title('Gráfico de Treino : Perda')
plt.plot(epoch_vec, loss_train_history, label='loss')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.show()

# %%
plt.title('Gráfico de Validação : Perda')
plt.plot(epoch_vec, loss_valid_history, label='loss')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.show()

# %%
model.load_state_dict(torch.load('models/best_model_trab4.pt'))

# %%
predictions_torch = model(torch.tensor(x_test.astype(np.float32)));
predictions_np = predictions_torch.detach().numpy()
predictions = scaler.inverse_transform(predictions_np.reshape(-1,1))

# %%
test_loss = loss_fn(predictions_torch, torch.tensor(y_test.astype(np.float32)))/len(y_test)
print(f"Test Error: Avg loss = {test_loss.item():>8f}")
test_loss

# %%
data = stock_data.filter(['Close'])
train = data[:training_data_len]
validation = data[training_data_len:]
validation['Predictions'] = predictions
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.plot(train)
plt.plot(validation[['Close', 'Predictions']])
plt.legend(['Train', 'Test', 'Predictions'], loc='lower right')
plt.show()
